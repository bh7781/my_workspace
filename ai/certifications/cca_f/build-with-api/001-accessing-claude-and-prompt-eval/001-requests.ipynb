# %%
# %pip install anthropic python-dotenv

# %%
from dotenv import load_dotenv
load_dotenv(r"C:\Users\chinm\OneDrive\Workspace\portfolio\my_workspace\.env")

from anthropic import Anthropic

client = Anthropic()
model = "claude-haiku-4-5-20251001"

# %%
# message = client.messages.create(
#     model=model,
#     max_tokens=1000,
#     messages=[
#         {
#             "role": "user",
#             "content": "What is quantum computing? Answer in one sentence"
#         }
#     ]
# )

# %%
# message.content[0].text

# %%
# # List all available models programmatically
# models = client.models.list()

# for model in models:
#     print(f"Model ID: {model.id} | Name: {model.display_name}")

# %%
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages):
    message = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=messages,
    )
    return message.content[0].text

# %%
# # Start with an empty message list
# messages = []

# # Add the initial user question
# add_user_message(messages, "Who is Mahendra Singh Dhoni?")

# # Get Claude's response
# answer = chat(messages)

# # Add Claude's response to the conversation history
# add_assistant_message(messages, answer)

# # Add a follow-up question
# add_user_message(messages, "How many ICC trophies has he won?")

# # Add a follow-up question
# add_user_message(messages, "How many IPL trophies has he won?")

# # Add a follow-up question
# add_user_message(messages, "How many runs has he scored in his career?")

# # Get the follow-up response with full context
# final_answer = chat(messages)

# %%
# print(final_answer)

# %%
# print(messages)

# %% [markdown]
# # ChatBot

# %%
messages = []

while True:
    user_input = input("> ")
    print(">", user_input)

    add_user_message(messages, user_input)
    answer = chat(messages)
    add_assistant_message(messages, answer)
    print("Claude:", answer)
# Out:
# > who is MS Dhoni?
# Claude: # MS Dhoni
#
# **MS Dhoni** (Mahendra Singh Dhoni) is a legendary Indian cricketer, widely regarded as one of the greatest captains and wicketkeepers in cricket history.
#
# ## Key Facts:
#
# **Playing Career:**
# - Played for India from 2004-2019 (international cricket)
# - Wicketkeeper-batsman known for his explosive batting and calm demeanor
# - Captain of the Indian national team (2007-2016)
#
# **Major Achievements:**
# - Led India to win the **2011 Cricket World Cup** (ODI)
# - Won the **2007 ICC T20 World Cup** as captain
# - Won the **2013 Champions Trophy**
# - Known for his finishing abilities and big-match temperament
#
# **Domestic/Franchise Cricket:**
# - Played for **Chennai Super Kings** in the Indian Premier League (IPL)
# - One of the most successful IPL captains
#
# **Legacy:**
# - Transformed Indian cricket with his leadership
# - Known for his cool, calculated approach
# - Revolutionized the role of wicketkeeper in modern cricket
# ...
