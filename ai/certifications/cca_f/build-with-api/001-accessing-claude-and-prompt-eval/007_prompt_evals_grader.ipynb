# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5-20251001"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}
"""

    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 7

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "# AWS S3 Bucket Name Parser\n\nHere are several solutions to extract the bucket name from an S3 URI:\n\n## Solution 1: Simple String Splitting (Easiest)\n\n```python\ndef get_bucket_name(s3_uri):\n    \"\"\"Extract bucket name from S3 URI\"\"\"\n    # Remove 's3://' prefix and split by '/'\n    return s3_uri.replace('s3://', '').split('/')[0]\n\n# Test cases\nprint(get_bucket_name('s3://my-bucket-name/path/to/object'))  # Output: my-bucket-name\nprint(get_bucket_name('s3://bucket/'))  # Output: bucket\nprint(get_bucket_name('s3://my-bucket'))  # Output: my-bucket\n```\n\n## Solution 2: Using Regular Expressions (More Robust)\n\n```python\nimport re\n\ndef get_bucket_name(s3_uri):\n    \"\"\"Extract bucket name from S3 URI using regex\"\"\"\n    match = re.match(r's3://([^/]+)', s3_uri)\n    if match:\n        return match.group(1)\n    return None\n\n# Test cases\nprint(get_bucket_name('s3://my-bucket-name/path/to/object'))  # Output: my-bucket-name\nprint(get_bucket_name('s3://bucket'))  # Output: bucket\nprint(get_bucket_name('invalid-uri'))  # Output: None\n```\n\n## Solution 3: Using urllib (Best for URL Parsing)\n\n```python\nfrom urllib.parse import urlparse\n\ndef get_bucket_name(s3_uri):\n    \"\"\"Extract bucket name from S3 URI using urllib\"\"\"\n    parsed = urlparse(s3_uri)\n    return parsed.netloc\n\n# Test cases\nprint(get_bucket_name('s3://my-bucket-name/path/to/object'))  # Output: my-bucket-name\nprint(get_bucket_name('s3://bucket/folder/file.txt'))  # Output: bucket\n```\n\n## Solution 4: Using AWS SDK (boto3) - Production Ready\n\n```python\nfrom urllib.parse import urlparse\n\ndef get_bucket_name(s3_uri):\n    \"\"\"Extract bucket name from S3 URI - boto3 style\"\"\"\n    if not s3_uri.startswith('s3://'):\n        raise ValueError(\"Invalid S3 URI format\")\n    \n    parsed = urlparse(s3_uri)\n    if not parsed.netloc:\n        raise ValueError(\"No bucket name found in S3 URI\")\n    \n    return parsed.netloc\n\n# Test cases\ntry:\n    print(get_bucket_name('s3://my-bucket-name/path/to/object'))  # Output: my-bucket-name\n    print(get_bucket_name('invalid'))  # Raises ValueError\nexcept ValueError as e:\n    print(f\"Error: {e}\")\n```\n\n## Comparison\n\n| Solution | Pros | Cons |\n|----------|------|------|\n| **String Split** | Simple, fast | No validation |\n| **Regex** | Validates format, readable | Slightly slower |\n| **urllib** | Standard library, clean | Minimal validation |\n| **boto3 style** | Error handling, robust | More code |\n\n## Recommendation\n\n- **Quick scripts**: Use Solution 1 (string split)\n- **Production code**: Use Solution 3 or 4 (urllib with validation)\n- **Complex parsing**: Use Solution 2 (regex) for custom requirements",
#     "test_case": {
#       "task": "Parse an AWS S3 bucket name from a full S3 URI (e.g., 's3://my-bucket-name/path/to/object') and extract just the bucket name",
#       "format": "regex"
#     },
#     "score": 7,
#     "reasoning": "The solution effectively demonstrates multiple approaches with good pedagogical value and includes a production-ready option with error handling. However, the recommendation hierarchy is somewhat confusing (Solution 3 over 4 despite 4 being labeled 'Production Ready'), and important AWS S3 URI formats are omitted. The solutions work correctly for standard s3:// URIs but lack comprehensive validation and don't address common real-world S3 URL formats used in AWS tools and documentation."
#   },
#   {
#     "output": "# AWS Lambda Function JSON Configuration\n\nHere's a complete JSON configuration object for an AWS Lambda function:\n\n```json\n{\n  \"FunctionName\": \"my-lambda-function\",\n  \"Runtime\": \"python3.11\",\n  \"Role\": \"arn:aws:iam::ACCOUNT_ID:role/lambda-execution-role\",\n  \"Handler\": \"index.lambda_handler\",\n  \"MemorySize\": 256,\n  \"Timeout\": 30,\n  \"Environment\": {\n    \"Variables\": {\n      \"API_KEY\": \"your-api-key-here\",\n      \"DB_HOST\": \"your-database-host.rds.amazonaws.com\"\n    }\n  },\n  \"Description\": \"Lambda function with Python 3.11 runtime\",\n  \"TracingConfig\": {\n    \"Mode\": \"PassThrough\"\n  },\n  \"Tags\": {\n    \"Environment\": \"production\",\n    \"Project\": \"my-project\"\n  }\n}\n```\n\n## Key Configuration Details\n\n| Parameter | Value | Description |\n|-----------|-------|-------------|\n| **Runtime** | `python3.11` | Python 3.11 runtime environment |\n| **MemorySize** | `256` | Memory allocated in MB (128-10,240 MB) |\n| **Timeout** | `30` | Execution timeout in seconds (3-900 seconds) |\n| **Environment Variables** | `API_KEY`, `DB_HOST` | Custom environment variables |\n\n## Minimal Configuration\n\nIf you only need the required fields:\n\n```json\n{\n  \"Runtime\": \"python3.11\",\n  \"MemorySize\": 256,\n  \"Timeout\": 30,\n  \"Environment\": {\n    \"Variables\": {\n      \"API_KEY\": \"your-api-key-here\",\n      \"DB_HOST\": \"your-database-host.rds.amazonaws.com\"\n    }\n  }\n}\n```\n\n## Notes\n\n- Replace `ACCOUNT_ID` with your AWS account ID\n- Replace `your-api-key-here` and `your-database-host.rds.amazonaws.com` with actual values\n- Consider using AWS Secrets Manager for sensitive credentials instead of environment variables\n- The `Handler` field should point to your Lambda function entry point (e.g., `index.lambda_handler`)",
#     "test_case": {
#       "task": "Create a JSON configuration object for an AWS Lambda function that specifies the runtime as 'python3.11', memory as 256 MB, timeout as 30 seconds, and environment variables for API_KEY and DB_HOST",
#       "format": "json"
#     },
#     "score": 8,
#     "reasoning": "The solution correctly addresses all task requirements with accurate AWS Lambda configuration syntax. The inclusion of a minimal configuration example and security recommendations adds value. However, the full configuration conflates required and optional fields without clear distinction, and placeholder credentials could mislead users into unsafe practices. The core requirements are met correctly, but presentation could be more precisely targeted to the original request."
#   },
#   {
#     "output": "# AWS IAM User ARN Validator\n\nHere's a Python function that validates AWS IAM user ARNs:\n\n```python\nimport re\n\ndef is_valid_iam_user_arn(arn: str) -> bool:\n    \"\"\"\n    Validates if the provided string is a valid AWS IAM user ARN.\n    \n    Valid format: arn:aws:iam::account-id:user/username\n    \n    Args:\n        arn (str): The ARN string to validate\n        \n    Returns:\n        bool: True if the ARN is valid, False otherwise\n    \"\"\"\n    # Pattern explanation:\n    # ^arn:aws:iam:: - Literal prefix\n    # \\d{12} - Exactly 12 digits for AWS account ID\n    # :user/ - Literal separator\n    # [a-zA-Z0-9._-]+ - Username (alphanumeric, dots, underscores, hyphens)\n    # $ - End of string\n    \n    pattern = r'^arn:aws:iam::\\d{12}:user/[a-zA-Z0-9._\\-]+$'\n    return bool(re.match(pattern, arn))\n\n\n# Test cases\nif __name__ == \"__main__\":\n    # Valid ARNs\n    valid_arns = [\n        \"arn:aws:iam::123456789012:user/johndoe\",\n        \"arn:aws:iam::999999999999:user/john.doe\",\n        \"arn:aws:iam::000000000000:user/john_doe\",\n        \"arn:aws:iam::123456789012:user/john-doe\",\n        \"arn:aws:iam::123456789012:user/user123\",\n    ]\n    \n    # Invalid ARNs\n    invalid_arns = [\n        \"arn:aws:iam::12345678901:user/johndoe\",  # Account ID too short\n        \"arn:aws:iam::1234567890123:user/johndoe\",  # Account ID too long\n        \"arn:aws:iam::123456789012:role/johndoe\",  # Wrong resource type (role)\n        \"arn:aws:iam::123456789012:user/\",  # Missing username\n        \"arn:aws:iam::abc123456789:user/johndoe\",  # Non-numeric account ID\n        \"arn:aws:ec2::123456789012:user/johndoe\",  # Wrong service\n        \"arn:aws:iam::123456789012:user/john@doe\",  # Invalid character in username\n        \"123456789012:user/johndoe\",  # Missing prefix\n        \"\",  # Empty string\n        \"arn:aws:iam::123456789012:user/john doe\",  # Space in username\n    ]\n    \n    print(\"Testing valid ARNs:\")\n    for arn in valid_arns:\n        result = is_valid_iam_user_arn(arn)\n        status = \"\u2713\" if result else \"\u2717\"\n        print(f\"{status} {arn}: {result}\")\n    \n    print(\"\\nTesting invalid ARNs:\")\n    for arn in invalid_arns:\n        result = is_valid_iam_user_arn(arn)\n        status = \"\u2713\" if not result else \"\u2717\"\n        print(f\"{status} {arn}: {result}\")\n```\n\n## Output:\n```\nTesting valid ARNs:\n\u2713 arn:aws:iam::123456789012:user/johndoe: True\n\u2713 arn:aws:iam::999999999999:user/john.doe: True\n\u2713 arn:aws:iam::000000000000:user/john_doe: True\n\u2713 arn:aws:iam::123456789012:user/john-doe: True\n\u2713 arn:aws:iam::123456789012:user/user123: True\n\nTesting invalid ARNs:\n\u2713 arn:aws:iam::12345678901:user/johndoe:",
#     "test_case": {
#       "task": "Write a Python function that takes an AWS IAM user ARN and returns True if the ARN is valid (follows the format 'arn:aws:iam::account-id:user/username'), otherwise returns False",
#       "format": "python"
#     },
#     "score": 6,
#     "reasoning": "The solution demonstrates solid understanding of regex validation and AWS ARN structure. The core implementation correctly validates account ID format and basic resource structure. However, it has two significant issues: (1) the username character set is too restrictive compared to actual AWS IAM username rules, and (2) lacks defensive programming for non-string inputs. The incomplete test output raises concerns about whether all edge cases were properly tested. These issues would cause false negatives on valid IAM usernames containing characters like '@' or '+', limiting the function's real-world applicability."
#   }
# ]
