# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5-20251001"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}

* Respond only with Python, JSON, or a plain Regex
* Do not add any comments or commentary or explanation
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```code")
    output = chat(messages, stop_sequences=["```"])
    return output

# %%
# Functions to validate the output structure
import re
import ast


def validate_json(text):
    try:
        json.loads(text.strip())
        return 10
    except json.JSONDecodeError:
        return 0


def validate_python(text):
    try:
        ast.parse(text.strip())
        return 10
    except SyntaxError:
        return 0


def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10
    except re.error:
        return 0


def grade_syntax(response, test_case):
    format = test_case["format"]
    if format == "json":
        return validate_json(response)
    elif format == "python":
        return validate_python(response)
    else:
        return validate_regex(response)

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    model_score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    syntax_score = grade_syntax(output, test_case)

    score = (model_score + syntax_score) / 2

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 8.5

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "\nimport re\n\ndef extract_bucket_name(s3_uri):\n    match = re.match(r's3://([^/]+)', s3_uri)\n    return match.group(1) if match else None\n",
#     "test_case": {
#       "task": "Parse an AWS S3 bucket name from an S3 URI in the format 's3://bucket-name/key/path' and extract just the bucket name",
#       "format": "regex"
#     },
#     "score": 8.5,
#     "reasoning": "The solution correctly solves the core task with an appropriate regex pattern. However, it lacks defensive programming practices such as input validation and AWS bucket name constraint verification. Adding a type check and basic bucket name validation would make this production-ready. The current implementation is suitable for trusted inputs but risky in untrusted environments."
#   },
#   {
#     "output": "\n{\n  \"AWSTemplateFormatVersion\": \"2010-09-09\",\n  \"Description\": \"CloudFormation template for a Lambda function that prints Hello World\",\n  \"Resources\": {\n    \"LambdaExecutionRole\": {\n      \"Type\": \"AWS::IAM::Role\",\n      \"Properties\": {\n        \"AssumeRolePolicyDocument\": {\n          \"Version\": \"2012-10-17\",\n          \"Statement\": [\n            {\n              \"Effect\": \"Allow\",\n              \"Principal\": {\n                \"Service\": \"lambda.amazonaws.com\"\n              },\n              \"Action\": \"sts:AssumeRole\"\n            }\n          ]\n        },\n        \"ManagedPolicyArns\": [\n          \"arn:aws:iam::aws:policy/service-role/AWSLambdaBasicExecutionRole\"\n        ]\n      }\n    },\n    \"HelloWorldLambda\": {\n      \"Type\": \"AWS::Lambda::Function\",\n      \"Properties\": {\n        \"FunctionName\": \"HelloWorldFunction\",\n        \"Runtime\": \"python3.11\",\n        \"Role\": {\n          \"Fn::GetAtt\": [\n            \"LambdaExecutionRole\",\n            \"Arn\"\n          ]\n        },\n        \"Handler\": \"index.lambda_handler\",\n        \"Code\": {\n          \"ZipFile\": \"def lambda_handler(event, context):\\n    print('Hello World')\\n    return {\\n        'statusCode': 200,\\n        'body': 'Hello World'\\n    }\\n\"\n        }\n      }\n    }\n  },\n  \"Outputs\": {\n    \"LambdaFunctionArn\": {\n      \"Description\": \"ARN of the Lambda function\",\n      \"Value\": {\n        \"Fn::GetAtt\": [\n          \"HelloWorldLambda\",\n          \"Arn\"\n        ]\n      }\n    }\n  }\n}\n",
#     "test_case": {
#       "task": "Create a JSON CloudFormation template for an AWS Lambda function that prints 'Hello World' with basic execution role",
#       "format": "json"
#     },
#     "score": 9.0,
#     "reasoning": "The template is production-ready and correctly implements all core requirements: proper CloudFormation structure, appropriate IAM role with least-privilege execution permissions, and a functional Lambda function. The solution uses best practices like managed policies and intrinsic functions. Minor improvements would include more defensive code practices and additional function configuration properties. The interpretation of 'prints Hello World' as a return value rather than only console output is reasonable given typical API response patterns."
#   },
#   {
#     "output": "\nimport re\n\ndef parse_iam_arn(arn_string):\n    # AWS ARN format: arn:partition:service:region:account-id:resource-type/resource-id\n    pattern = r'^arn:aws:([a-z0-9\\-]+):([a-z0-9\\-]*):([a-z0-9\\-]*):([a-z0-9\\-]*):[a-z0-9\\-/:.]*([a-z0-9\\-]+)(?:[:/]|$)'\n    \n    # More comprehensive pattern to extract service and resource-type\n    pattern = r'^arn:aws:([a-z0-9\\-]+):[a-z0-9\\-]*:[a-z0-9\\-]*:[a-z0-9\\-]*:([a-z0-9\\-]+)'\n    \n    match = re.match(pattern, arn_string)\n    if match:\n        return {\n            \"service\": match.group(1),\n            \"resource_type\": match.group(2)\n        }\n    \n    # Alternative approach for different ARN formats\n    parts = arn_string.split(':')\n    if len(parts) >= 6:\n        service = parts[2]\n        resource_part = parts[5]\n        # Extract resource type (before / or as first part)\n        resource_type = resource_part.split('/')[0]\n        return {\n            \"service\": service,\n            \"resource_type\": resource_type\n        }\n    \n    return None\n\n# Test cases\nprint(parse_iam_arn(\"arn:aws:iam::123456789012:user/Development/product_1203/*\"))\nprint(parse_iam_arn(\"arn:aws:iam::123456789012:role/service-role\"))\nprint(parse_iam_arn(\"arn:aws:s3:::my-bucket/*\"))\nprint(parse_iam_arn(\"arn:aws:ec2:us-east-1:123456789012:instance/i-1234567890abcdef0\"))\n",
#     "test_case": {
#       "task": "Write a Python function that takes an AWS IAM ARN string and returns the service and resource type components",
#       "format": "python"
#     },
#     "score": 8.0,
#     "reasoning": "The solution partially works due to the string-splitting fallback method, which handles real-world ARNs reasonably well. However, the regex pattern is ineffective and suggests incomplete understanding of AWS ARN complexity. The code lacks robustness through proper validation and error handling. While functional for basic cases, it would benefit from removing dead code (the regex), improving resource type parsing for colon-separated formats, and adding input validation with appropriate error messages."
#   }
# ]
