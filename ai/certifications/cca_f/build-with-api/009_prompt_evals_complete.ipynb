# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5-20251001"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex",
        "solution_criteria": "Key criteria for evaluating the solution"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Criteria you should use to evaluate the solution:
<criteria>
{test_case["solution_criteria"]}
</criteria>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}

* Respond only with Python, JSON, or a plain Regex
* Do not add any comments or commentary or explanation
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```code")
    output = chat(messages, stop_sequences=["```"])
    return output

# %%
# Functions to validate the output structure
import re
import ast


def validate_json(text):
    try:
        json.loads(text.strip())
        return 10
    except json.JSONDecodeError:
        return 0


def validate_python(text):
    try:
        ast.parse(text.strip())
        return 10
    except SyntaxError:
        return 0


def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10
    except re.error:
        return 0


def grade_syntax(response, test_case):
    format = test_case["format"]
    if format == "json":
        return validate_json(response)
    elif format == "python":
        return validate_python(response)
    else:
        return validate_regex(response)

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    model_score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    syntax_score = grade_syntax(output, test_case)

    score = (model_score + syntax_score) / 2

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 8.166666666666666

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "\nimport json\nimport sys\n\ndef extract_ec2_instances(template):\n    if isinstance(template, str):\n        template = json.loads(template)\n    \n    resources = template.get('Resources', {})\n    ec2_instances = {}\n    \n    for logical_id, resource in resources.items():\n        if resource.get('Type') == 'AWS::EC2::Instance':\n            instance_type = resource.get('Properties', {}).get('InstanceType', 'Not specified')\n            ec2_instances[logical_id] = instance_type\n    \n    return ec2_instances\n\nif __name__ == '__main__':\n    template_input = sys.stdin.read()\n    result = extract_ec2_instances(template_input)\n    print(json.dumps(result, indent=2))\n",
#     "test_case": {
#       "task": "Parse an AWS CloudFormation template and extract all EC2 instance logical IDs and their instance types",
#       "format": "python",
#       "solution_criteria": "Function should parse JSON CloudFormation template, iterate through Resources, filter for AWS::EC2::Instance type, and return a dictionary mapping logical IDs to instance types"
#     },
#     "score": 8.5,
#     "reasoning": "The solution successfully meets the core requirements: it parses CloudFormation templates, iterates through Resources, filters for EC2 instances, and returns a dictionary of logical IDs to instance types. The code is clean and readable. However, it lacks robustness in error handling for malformed JSON and doesn't account for dynamic instance type references using CloudFormation functions, which are common in real-world templates. These are relatively minor issues for a basic parsing task."
#   },
#   {
#     "output": "\n{\n  \"Version\": \"2012-10-17\",\n  \"Statement\": [\n    {\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:GetObject\",\n        \"s3:ListBucket\"\n      ],\n      \"Resource\": [\n        \"arn:aws:s3:::company-data\",\n        \"arn:aws:s3:::company-data/*\"\n      ]\n    }\n  ]\n}\n",
#     "test_case": {
#       "task": "Create a JSON policy document that allows an IAM user to read and list objects in a specific S3 bucket named 'company-data'",
#       "format": "json",
#       "solution_criteria": "Valid IAM policy JSON with correct structure, Principal/Effect/Action/Resource fields, s3:GetObject and s3:ListBucket permissions scoped to the 'company-data' bucket ARN"
#     },
#     "score": 8.5,
#     "reasoning": "The policy correctly grants the required permissions and targets the correct bucket. However, it violates IAM best practice by applying s3:ListBucket (a bucket-level operation) to both the bucket and object ARNs. ListBucket should only apply to the bucket ARN. A corrected version would use separate statements or conditionally scope the actions. The policy is functionally workable but not optimally structured."
#   },
#   {
#     "output": "\n^/aws/lambda/[a-zA-Z0-9_-]+$\n",
#     "test_case": {
#       "task": "Write a regular expression to validate and extract AWS Lambda function names from CloudWatch logs (format: /aws/lambda/function-name)",
#       "format": "regex",
#       "solution_criteria": "Regex should match the path pattern /aws/lambda/ followed by valid function names (alphanumeric, hyphens, underscores), and capture the function name without the prefix"
#     },
#     "score": 7.5,
#     "reasoning": "The regex successfully validates the path format and pattern matching requirements, but falls short on the extraction requirement specified in the criteria. The solution needs a capturing group around the function name portion to enable extraction without the /aws/lambda/ prefix. Additionally, it's overly restrictive by excluding dots, which are permissible in Lambda function names, and lacks length constraints that align with AWS specifications."
#   }
# ]
