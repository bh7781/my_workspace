# %%
# %pip install anthropic python-dotenv

# %%
from dotenv import load_dotenv
load_dotenv()

from anthropic import Anthropic

client = Anthropic()
model = "claude-haiku-4-5-20251001"

# %%
# message = client.messages.create(
#     model=model,
#     max_tokens=1000,
#     messages=[
#         {
#             "role": "user",
#             "content": "What is quantum computing? Answer in one sentence"
#         }
#     ]
# )

# %%
# message.content[0].text

# %%
# # List all available models programmatically
# models = client.models.list()

# for model in models:
#     print(f"Model ID: {model.id} | Name: {model.display_name}")

# %%
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages):
    message = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=messages,
    )
    return message.content[0].text

# %%
# Start with an empty message list
messages = []

# Add the initial user question
add_user_message(messages, "Who is Mahendra Singh Dhoni?")

# Get Claude's response
answer = chat(messages)

# Add Claude's response to the conversation history
add_assistant_message(messages, answer)

# Add a follow-up question
add_user_message(messages, "How many ICC trophies has he won?")

# Get the follow-up response with full context
final_answer = chat(messages)

# %%
print(final_answer)
# Out:
# # Mahendra Singh Dhoni's ICC Trophies
#
# Mahendra Singh Dhoni won **3 ICC trophies** as captain of India:
#
# 1. **2007 ICC World Twenty20** (T20 World Cup)
# 2. **2011 ICC Cricket World Cup** (ODI World Cup)
# 3. **2013 ICC Champions Trophy** (ODI)
#
# These are widely considered his most significant achievements and represent India's major ICC tournament victories during his captaincy era.

# %%
print(messages)
# Out:
# [{'role': 'user', 'content': 'Who is Mahendra Singh Dhoni?'}, {'role': 'assistant', 'content': '# Mahendra Singh Dhoni\n\nMahendra Singh Dhoni is a legendary Indian cricketer and former captain of the Indian national cricket team. Here are his key highlights:\n\n## Career Achievements\n- **Wicket-keeper batsman** known for his exceptional finishing skills and tactical acumen\n- **Led India to three major ICC titles:**\n  - 2007 ICC World Twenty20\n  - 2011 ICC Cricket World Cup\n  - 2013 ICC Champions Trophy\n\n## Playing Style\n- Famous for his calm demeanor under pressure\n- Innovative batting, particularly in limited-overs cricket\n- One of the most successful captains in cricket history\n\n## IPL & Franchise Cricket\n- Plays for Chennai Super Kings in the Indian Premier League\n- Known as "Captain Cool" for his composed leadership style\n\n## Career Timeline\n- Made his international debut in 2004\n- Captained India from 2007-2016 (and briefly after)\n- Retired from Test cricket in 2014\n- Stepped back from international cricket in 2020\n\n## Legacy\n- Regarded as one of cricket\'s greatest finishers and captains\n- Revolutionized wicket-keeper batting in limited-overs formats\n- Remains influential in Indian cricket as a senior player and leader\n\nIs there a specific aspect of his career you\'d like to know more about?'}, {'role': 'user', 'content': 'How many ICC trophies has he won?'}]
