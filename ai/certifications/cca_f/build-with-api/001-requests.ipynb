# %%
# %pip install anthropic python-dotenv

# %%
from dotenv import load_dotenv
load_dotenv(r"C:\Users\chinm\OneDrive\Workspace\portfolio\my_workspace\.env")

from anthropic import Anthropic

client = Anthropic()
model = "claude-haiku-4-5-20251001"

# %%
# message = client.messages.create(
#     model=model,
#     max_tokens=1000,
#     messages=[
#         {
#             "role": "user",
#             "content": "What is quantum computing? Answer in one sentence"
#         }
#     ]
# )

# %%
# message.content[0].text

# %%
# # List all available models programmatically
# models = client.models.list()

# for model in models:
#     print(f"Model ID: {model.id} | Name: {model.display_name}")

# %%
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages):
    message = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=messages,
    )
    return message.content[0].text

# %%
# Start with an empty message list
messages = []

# Add the initial user question
add_user_message(messages, "Who is Mahendra Singh Dhoni?")

# Get Claude's response
answer = chat(messages)

# Add Claude's response to the conversation history
add_assistant_message(messages, answer)

# Add a follow-up question
add_user_message(messages, "How many ICC trophies has he won?")

# Add a follow-up question
add_user_message(messages, "How many IPL trophies has he won?")

# Add a follow-up question
add_user_message(messages, "How many runs has he scored in his career?")

# Get the follow-up response with full context
final_answer = chat(messages)

# %%
print(final_answer)
# Out:
# # Mahendra Singh Dhoni's Trophy and Stats Record
#
# ## ICC Trophies Won (as Captain)
# - **3 major ICC trophies**:
#   1. 2007 ICC T20 World Cup
#   2. 2011 Cricket World Cup (ODI)
#   3. 2013 ICC Champions Trophy
#
# ## IPL Trophies Won (as Captain)
# - **5 IPL titles** with Chennai Super Kings:
#   1. 2010
#   2. 2011
#   3. 2018
#   4. 2021
#   5. 2023
#
# ## International Career Runs (All Formats)
# - **Test**: ~4,876 runs
# - **ODI**: ~10,773 runs
# - **T20I**: ~1,617 runs
# - **Total**: Approximately **17,000+ international runs**
#
# ## Additional Notes
# - He's the only captain to win all three ICC ODI trophies (World Cup, Champions Trophy, and T20 World Cup)
# - His IPL success with Chennai Super Kings is unmatched
# - His batting average in ODIs was around 50.57, reflecting his consistency
#
# These records cement his legacy as one of cricket's greatest all-around players and leaders.

# %%
print(messages)
# Out:
# [{'role': 'user', 'content': 'Who is Mahendra Singh Dhoni?'}, {'role': 'assistant', 'content': '# Mahendra Singh Dhoni\n\nMahendra Singh Dhoni is a legendary Indian cricketer and one of the most successful leaders in cricket history. Here are the key highlights:\n\n## Playing Career\n- **Position**: Wicketkeeper-batsman\n- **International debut**: 2004\n- **Retirement**: 2020 (international cricket)\n- Played for India in Test, ODI, and T20 formats\n\n## Major Achievements\n- **2007 ICC T20 World Cup**: Won as captain\n- **2011 Cricket World Cup**: Won as captain (ODI)\n- **2013 Champions Trophy**: Won as captain\n- Led India to #1 ranking in Test cricket\n- One of the greatest finishers in limited-overs cricket\n\n## Captain Record\n- Captained India for 200 Test matches\n- Known for his calm demeanor and innovative strategies\n- Considered one of cricket\'s best captains\n\n## IPL\n- Founded and captained Chennai Super Kings\n- Multiple IPL titles as captain\n\n## Personal\n- Nicknamed "MSD" or "Captain Cool"\n- Known for his aggressive batting and exceptional leadership\n- Remains iconic in Indian sports culture\n\nHe\'s widely regarded as one of the greatest wicketkeeper-batsmen and captains in cricket history, with a lasting impact on the sport.'}, {'role': 'user', 'content': 'How many ICC trophies has he won?'}, {'role': 'user', 'content': 'How many IPL trophies has he won?'}, {'role': 'user', 'content': 'How many runs has he scored in his career?'}]
