# %%
import random

# %%
random.randint(1, 6)
# Out:
# 1

# %%
random.random()
# Out:
# 0.7252419452786294

# %%
random.uniform(1, 10)
# Out:
# 2.0862794437594245

# %%
# Coin Toss
if random.randint(0, 1) == 0:
    print("Heads")
else:
    print("Tails")
# Out:
# Heads

# %%
states_of_usa = ["Alabama", "Alaska", "Arizona", "Arkansas", "California", "Colorado", "Connecticut", "Delaware", "Florida", "Georgia",
                 "Hawaii", "Idaho", "Illinois", "Indiana", "Iowa", "Kansas", "Kentucky", "Louisiana", "Maine", "Maryland",
                 "Massachusetts", "Michigan", "Minnesota", "Mississippi", "Missouri", "Montana", "Nebraska", "Nevada", "New Hampshire", "New Jersey",
                 "New Mexico", "New York", "North Carolina", "North Dakota", "Ohio", "Oklahoma", "Oregon", "Pennsylvania", "Rhode Island", "South Carolina",
                 "South Dakota", "Tennessee", "Texas", "Utah", "Vermont", "Virginia", "Washington", "West Virginia", "Wisconsin", "Wyoming"]

# %%
states_of_usa[0]
# Out:
# 'Alabama'

# %%
states_of_usa[46]
# Out:
# 'Washington'

# %%
states_of_usa[-1]
# Out:
# 'Wyoming'

# %%
states_of_usa[-2]
# Out:
# 'Wisconsin'

# %%
states_of_usa[0] = "Aladdin"

# %%
print(states_of_usa)
# Out:
# ['Aladdin', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming']

# %%
states_of_usa.append("Asguard")

# %%
print(states_of_usa)
# Out:
# ['Aladdin', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming', 'Asguard']

# %%
states_of_usa.extend(["Wakanda", "Sakaar", "Nidavellir"])

# %%
print(states_of_usa)
# Out:
# ['Aladdin', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming', 'Asguard', 'Wakanda', 'Sakaar', 'Nidavellir']

# %%
# Code Challenge: Who will pay the bill?
friends = ["Thor", "Iron Man", "Spider Man", "Hulk", "Captain America", "Winter Soldier", "Dr. Strange"]
print(f"No. of friends: {len(friends)}")

# Option 1
print(f"Today's bill will be paid by : {random.choice(friends)}")

# Option 2
print(f"Today's bill will be paid by : {friends[random.randint(0, len(friends)-1)]}")
# Out:
# No. of friends: 7
# Today's bill will be paid by : Captain America
# Today's bill will be paid by : Winter Soldier

# %%
states_of_usa[len(states_of_usa)]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[204], line 1
# ----> 1 states_of_usa[len(states_of_usa)]
#
# IndexError: list index out of range

# %% [markdown]
# # Working with Nested Lists

# %%
fruits = ["Strawberries", "Nectarines", "Apples", "Grapes", "Peaches", "Cherries", "Pears"]
vegetables = ["Spinach", "Kale", "Tomatoes", "Celery", "Potatoes"]

# List of food items that may get impacted due to pesticides
dirty_dozen = [fruits, vegetables]

# %%
print(dirty_dozen)
# Out:
# [['Strawberries', 'Nectarines', 'Apples', 'Grapes', 'Peaches', 'Cherries', 'Pears'], ['Spinach', 'Kale', 'Tomatoes', 'Celery', 'Potatoes']]

# %%
print(dirty_dozen[1][1])
# Out:
# Kale

# %%
print(dirty_dozen[0][-1])
# Out:
# Pears

# %%
print(dirty_dozen[-1][-2])
# Out:
# Celery
