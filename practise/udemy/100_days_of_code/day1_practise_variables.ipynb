# %%
# This is a single line comment
print(f'Hello {input('What is your name?: ')}!')
# Out:
# Hello black_hat!

# %%
# !python --version
# Out:
# Python 3.14.0

# %% [markdown]
# # Variables

# %%
name = input('What is your name?')

# %%
name
# Out:
# 'black_hat'

# %%
print(f'Length of string "{name}" is {len(name)}')
# Out:
# Length of string "black_hat" is 9

# %%
username = input('What is your name?: ')

# %%
length = len(username)

# %%
print(length)
# Out:
# 9
